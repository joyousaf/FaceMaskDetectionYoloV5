# %% [markdown]
# <a href="https://colab.research.google.com/github/joyousaf/FaceMaskDetectionYoloV5_Django/blob/main/YoloModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !git clone https://github.com/spacewalk01/face-mask-detection
# Out:
# Cloning into 'face-mask-detection'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 117 (delta 11), reused 11 (delta 11), pack-reused 101
# Receiving objects: 100% (117/117), 58.98 MiB | 15.69 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# !cd /content/face-mask-detection

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16057, done.
# remote: Total 16057 (delta 0), reused 0 (delta 0), pack-reused 16057
# Receiving objects: 100% (16057/16057), 14.66 MiB | 23.57 MiB/s, done.
# Resolving deltas: 100% (11028/11028), done.

# %%
# Install yolov5
#!git clone https://github.com/ultralytics/yolov5
# !cd /content/yolov5

# %%
# !pip install -r /content/yolov5/requirements.txt

# %%
# !cd /content/face-mask-detection

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d andrewmvd/face-mask-detection
# Out:
# ...
# face-mask-detection.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !pwd
# Out:
# /content

# %%
# !cd /content/

# %%
# !python /content/face-mask-detection/prepare.py
# Out:
# 100% 853/853 [00:00<00:00, 5277.60it/s]

# %%
# !cd /content/yolov5

# %%
# !python /content/yolov5/train.py --img 640 --batch 16 --epochs 100 --data /content/face-mask-detection/mask_config.yaml --weights yolov5s.pt --workers 0
# Out:
# 2023-11-05 05:57:53.166816: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-05 05:57:53.166878: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-05 05:57:53.166910: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python /content/yolov5/detect.py --source /content/face-mask-detection/datasets/input.mp4 --weights /content/face-mask-detection/models/mask_yolov5.pt --conf 0.2
# Out:
# detect: weights=['/content/face-mask-detection/models/mask_yolov5.pt'], source=/content/face-mask-detection/datasets/input.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/452) /content/face-mask-detection/datasets/input.mp4: 384x640 12 with_masks, 45.0ms
# video 1/1 (2/452) /content/face-mask-detection/datasets/input.mp4: 384x640 13 with_masks, 6.1ms
# ...

# %%
# !python /content/yolov5/detect.py --source /content/download.jpg --weights /content/face-mask-detection/models/mask_yolov5.pt --conf 0.2
# Out:
# detect: weights=['/content/face-mask-detection/models/mask_yolov5.pt'], source=/content/download.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/download.jpg: 384x640 1 with_mask, 39.3ms
# Speed: 0.4ms pre-process, 39.3ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp4

# %%
# Convert weights to fp16 TFLite model

# !python /content/yolov5/export.py --weights /content/face-mask-detection/models/mask_yolov5.pt --include tflite --img 640
# Out:
# export: data=yolov5/data/coco128.yaml, weights=['/content/face-mask-detection/models/mask_yolov5.pt'], imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.10.12 torch-2.1.0+cu118 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/face-mask-detection/models/mask_yolov5.pt with output shape (1, 25200, 8) (13.8 MB)
# 2023-11-07 17:36:33.412184: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python /content/yolov5/detect.py --source /content/face-mask-detection/datasets/input.mp4 --weights /content/face-mask-detection/models/mask_yolov5-fp16.tflite --conf 0.2
# Out:
# detect: weights=['/content/face-mask-detection/models/mask_yolov5-fp16.tflite'], source=/content/face-mask-detection/datasets/input.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# 2023-11-07 17:39:40.700044: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !cp -r /content/face-mask-detection/models/mask_yolov5_saved_model /content/drive/MyDrive/Colab\ Notebooks/Mobile\ Web\ Service\ Programming/Mid/
# !cp -r /content/face-mask-detection/models/mask_yolov5-fp16.tflite /content/drive/MyDrive/Colab\ Notebooks/Mobile\ Web\ Service\ Programming/Mid/
# !cp -r /content/face-mask-detection/models/mask_yolov5.pt /content/drive/MyDrive/Colab\ Notebooks/Mobile\ Web\ Service\ Programming/Mid/
